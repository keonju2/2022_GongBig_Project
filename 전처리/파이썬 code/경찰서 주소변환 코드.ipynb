# %%
import pandas as pd #판다스 호출
import numpy as np#넘파이 호출

# %%
data1=pd.read_excel('경찰주소.xlsx',encoding)#경찰 데이터 호출

# %%
data1#데이터확인
# Out:
#       지방청   경찰서 관서명   구분                         주소         위도          경도
# 0     서울청  서울중부  을지  지구대          서울특별시 중구  을지로 234  37.566026  126.985473
# 1     서울청  서울중부  광희  지구대        서울특별시 중구  퇴계로 375-1  37.565265  127.013346
# 2     서울청  서울중부  약수  지구대           서울특별시 중구  동호로 15  37.557966  127.008204
# 3     서울청  서울중부  신당  파출소         서울특별시 중구  다산로 248   37.562998  127.015381
# 4     서울청  서울중부  장충  파출소          서울특별시 중구  동호로 261  37.557966  127.008204
# ...   ...   ...  ..  ...                        ...        ...         ...
# 2026  제주청   서귀포  안덕  파출소   제주특별자치도 서귀포시 안덕면 화순로 116        NaN         NaN
# 2027  제주청   서귀포  대정  파출소  제주특별자치도 서귀포시 대정읍 상모로 310         NaN         NaN
# 2028  제주청   서귀포  중문  파출소     제주특별자치도 서귀포시  천제연로 165        NaN         NaN
# 2029  제주청   서귀포  대신  파출소  제주특별자치도 서귀포시  신서귀로51번길 18        NaN         NaN
# 2030  제주청   서귀포  효돈  파출소    제주특별자치도 서귀포시  효돈로 171-1        NaN         NaN
#
# [2031 rows x 7 columns]

# %%
data2=data1[data1['지방청']=='서울청']
address=data2['주소']
address1=[]
for i in range(len(address)):
    a = address[i].split(' ')
    b=address[i] = " ".join(a[0:5])
    address1.append(b)
data2['전처리 주소']=address1
address1
 
#게오코딩을 위한 도로명 주소 반환
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_604\1941996704.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   b=address[i] = " ".join(a[0:5])
# C:\Users\user\AppData\Local\Temp\ipykernel_604\1941996704.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2['전처리 주소']=address1
# ['서울특별시 중구  을지로 234',
#  '서울특별시 중구  퇴계로 375-1',
#  '서울특별시 중구  동호로 15',
#  '서울특별시 중구  다산로 248',
#  '서울특별시 중구  동호로 261',
#  '서울특별시 중구  퇴계로 178',
#  '서울특별시 중구 충무로 56-1',
#  '서울특별시 종로구  종로17길 4',
#  '서울특별시 종로구  삼일대로 386',
#  '서울특별시 종로구  세검정로 226',
#  '서울특별시 종로구  평창문화로 46',
# ...

# %%
address1[118]# 도로명 주소 확인
# Out:
# '서울특별시 강북구  삼양로 305'

# %%
from geopy.geocoders import Nominatim
geo_local=Nominatim(user_agent='South Korea')

def geocoding(address):
    geolocoder = Nominatim(user_agent = 'South Korea', timeout=None)
    geo = geolocoder.geocode(address)
    crd = {"lat": str(geo.latitude), "lng": str(geo.longitude)}

    return crd
latitude=[]
longitude=[]
crd = geocoding("서울특별시 강남구 개포로 261")
print(crd['lat'])
print(crd['lng'])
latitude.append(crd['lat'])
longitude.append(crd['lng'])
#각 도로명 주소에 해당하는 위도 경도 반환
# Out:
# 37.4913783
# 127.0727055
